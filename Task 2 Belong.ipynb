# %% [markdown]
# ## Customer Details:
#
# ### Name- name of the customer
# ### CustomerID- Unique ID of a customer
# ### Age - The age of the individual
# ### Marital Status- Status of the customer( Married/Unmarried/Widow/Separated/Divorced)
# ### Gender - Gender of the individual
# ### Ethnicity - Ethnicity of the individual
# ### Education - Education level

# %% [markdown]
# ********************************************************************************************************************************

# %% [markdown]
# ## Card Details:
#
# ### CustomerID- Unique ID of a customer
# ### Income - Income of the individual (Lakhs)
# ### Limit  - Current credit card limit
# ### Rating - Credit rating of the individual
# ### Cards - Number of cards the individual has
# ### Balance - Current account balance of the individual (Thousands)

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Task -Data Cleaning & Visualization
#
# #### Python
#
# ### The importance of data cleaning in the development of machine learning models cannot be overstated as it ensures that the model is trained on clean and unbiased data, resulting in more accurate predictions and decisions. By identifying and addressing errors and biases in the data, data cleaning plays a crucial role in enhancing the performance of machine learning models.
#
# ### -> Join datasets of different formats using Python based on common fields.
# ### -> Clean the data by removing duplicate, missing, and irrelevant values.
# ### -> Analyze the data to understand its characteristics and trends.
# ### -> Address any errors or inconsistencies in the data.
# ### -> Ensure that the data is suitable for analysis

# %% [markdown]
# ## Importing the necessary Library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading the Data Sets

# %%
df1= pd.read_csv('Customer Details.csv', encoding = 'latin1')
df1.head()
# Out:
#                  Name    CustomerID  Age Marital Status  Gender  \
# 0  Katherine Bettcher    0002-ORFBO   30        Married    Male
# 1    Alejandro Graham   0002-ORFBOA   71        Married    Male
# 2       Priscilla Ian   0002-ORFBOC   46      Seperated    Male
# 3              Ovella  0002-ORFBOCH   42        Married  Female
# 4             Juliann   0002-ORFBOH   30        Married    Male
#
#           Ethnicity         Education
# 0         Caucasian            Master
# 1             Asian          Bachelor
# 2  African American  Senior Secondary
# 3         Caucasian  Senior Secondary
# 4  African American         Doctorate

# %%
df2= pd.read_csv('Card Details.csv')
df2.head()
# Out:
#      CustomerID   Income  Limit  Rating  Cards  Balance
# 0    0002-ORFBO  105.038   9142     734      3      232
# 1   0002-ORFBOA   69.820   4223     389      1      924
# 2   0002-ORFBOC   17.441   2430     253      1       20
# 3  0002-ORFBOCH   39.368   3829     248      3      813
# 4   0002-ORFBOH   56.375   2850     258      1      109

# %% [markdown]
# ## Joining the two data sets

# %%
df_raw = pd.merge(df2, df1, on = 'CustomerID')

# %%
df_raw.head()
# Out:
#      CustomerID   Income  Limit  Rating  Cards  Balance                Name  \
# 0    0002-ORFBO  105.038   9142     734      3      232  Katherine Bettcher
# 1   0002-ORFBOA   69.820   4223     389      1      924    Alejandro Graham
# 2   0002-ORFBOC   17.441   2430     253      1       20       Priscilla Ian
# 3  0002-ORFBOCH   39.368   3829     248      3      813              Ovella
# 4   0002-ORFBOH   56.375   2850     258      1      109             Juliann
#
#    Age Marital Status  Gender         Ethnicity         Education
# 0   30        Married    Male         Caucasian            Master
# 1   71        Married    Male             Asian          Bachelor
# 2   46      Seperated    Male  African American  Senior Secondary
# 3   42        Married  Female         Caucasian  Senior Secondary
# 4   30        Married    Male  African American         Doctorate

# %%
df_raw.shape
# Out:
# (32547, 12)

# %%
df = df_raw.copy()

# %% [markdown]
# # TASK 2

# %% [markdown]
# ### Conduct comprehensive exploratory data analysis (EDA) to gain deep insights into the dataset.

# %% [markdown]
# **Dropping the Unnecessary columns**

# %%
df = df.drop('Name', axis = 'columns')

# %%
df = df.drop('CustomerID', axis = 'columns')

# %%
df
# Out:
#         Income  Limit  Rating  Cards  Balance  Age Marital Status  Gender  \
# 0      105.038   9142     734      3      232   30        Married    Male
# 1       69.820   4223     389      1      924   71        Married    Male
# 2       17.441   2430     253      1       20   46      Seperated    Male
# 3       39.368   3829     248      3      813   42        Married  Female
# 4       56.375   2850     258      1      109   30        Married    Male
# ...        ...    ...     ...    ...      ...  ...            ...     ...
# 32542   32.930   4222     308      4      162   34      Unmarried    Male
# 32543   12.469   5645     311      2      487   61        Married  Female
# 32544   64.167   3116     285      3      576   64      Unmarried    Male
# 32545   20.970   1356     161      2        0   77      Unmarried  Female
# 32546   35.337   3663     261      5      176   47      Unmarried  Female
#
#               Ethnicity           Education
# 0             Caucasian              Master
# 1                 Asian            Bachelor
# 2      African American    Senior Secondary
# 3             Caucasian    Senior Secondary
# 4      African American           Doctorate
# ...                 ...                 ...
# 32542         Caucasian            Bachelor
# 32543         Caucasian  Senior High School
# 32544         Caucasian    Senior Secondary
# 32545         Caucasian            Bachelor
# 32546         Caucasian              Master
#
# [32547 rows x 10 columns]

# %%
# Looking at the shape of the data
print('The Number of rows and columns present in the data set is: ',df.shape)
# Out:
# The Number of rows and columns present in the data set is:  (32547, 10)

# %%
# Checking the data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32547 entries, 0 to 32546
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Income          32547 non-null  float64
#  1   Limit           32547 non-null  int64
#  2   Rating          32547 non-null  int64
#  3   Cards           32547 non-null  int64
#  4   Balance         32547 non-null  int64
#  5   Age             32547 non-null  int64
#  6   Marital Status  32547 non-null  object
#  7   Gender          32547 non-null  object
#  8   Ethnicity       32547 non-null  object
#  9   Education       32547 non-null  object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 2.7+ MB

# %% [markdown]
# ## Seperating the Categorical and Continuous Values

# %%
cat_vars = []
cont_vars = []

for i in df.columns:
    if df[i].dtypes=='object':
        cat_vars.append(i)
    else:
        cont_vars.append(i)
    
print("Categorical Variables: ",cat_vars)
print("Continuous Variables: ", cont_vars)
# Out:
# Categorical Variables:  ['Marital Status', 'Gender', 'Ethnicity', 'Education']
# Continuous Variables:  ['Income', 'Limit', 'Rating', 'Cards', 'Balance', 'Age']

# %% [markdown]
# ## Looking at the Unique and  Null values

# %%
for i in cat_vars:
    nunique=df[i].nunique()
    print("*************************************************")
    print(i)
    print("the number of unique levels are: ",nunique)
    print("\n")
    print(df[i].value_counts())
    print("\n")
    print("the number of Null values are: ", df[i].isnull().sum())
# Out:
# *************************************************
# Marital Status
# the number of unique levels are:  5
#
#
# Unmarried    16829
# Married      15621
# Divorced        51
# Seperated       37
# Widow            9
# Name: Marital Status, dtype: int64
#
#
# the number of Null values are:  0
# *************************************************
# Gender
# the number of unique levels are:  2
#
#
# Female    16562
# Male      15985
# Name: Gender, dtype: int64
#
#
# the number of Null values are:  0
# *************************************************
# Ethnicity
# the number of unique levels are:  3
#
#
# Caucasian           16380
# Asian                8240
# African American     7927
# Name: Ethnicity, dtype: int64
#
#
# the number of Null values are:  0
# *************************************************
# Education
# the number of unique levels are:  8
#
#
# Master                8781
# Bachelor              7342
# Senior Secondary      5270
# Elementary            3793
# Doctorate             2610
# Senior High School    2553
# Secondary             1733
# High School            465
# Name: Education, dtype: int64
#
#
# the number of Null values are:  0

# %%
for i in cont_vars:
    nunique=df[i].nunique()
    print("*************************************************")
    print(i)
    print("the number of unique levels are: ",nunique)
    print("\n")
    print(df[i].value_counts())
    print("\n")
    print("the number of Null values are: ", df[i].isnull().sum())
# Out:
# *************************************************
# Income
# the number of unique levels are:  24384
#
#
# 10.726     211
# 10.742     196
# 10.735     186
# 10.627     170
# 10.635     164
#           ...
# 119.753      1
# 39.689       1
# 44.158       1
# 50.156       1
# 64.167       1
# Name: Income, Length: 24384, dtype: int64
#
#
# the number of Null values are:  0
# *************************************************
# Limit
# the number of unique levels are:  7443
#
#
# 1160     183
# 1300     176
# 10578    173
# 10673    168
# 1134     167
#         ...
# 9519       1
# 1679       1
# 8842       1
# 6358       1
# 9290       1
# Name: Limit, Length: 7443, dtype: int64
#
#
# the number of Null values are:  0
# *************************************************
# Rating
# the number of unique levels are:  679
#
#
# 126    275
# 120    267
# 122    260
# 121    241
# 281    199
#       ...
# 804      1
# 749      1
# 801      1
# 794      1
# 740      1
# Name: Rating, Length: 679, dtype: int64
#
#
# the number of Null values are:  0
# *************************************************
# Cards
# the number of unique levels are:  7
#
#
# 3    9575
# 2    9038
# 4    5157
# 1    4556
# 5    3006
# 6     917
# 7     298
# Name: Cards, dtype: int64
#
#
# the number of Null values are:  0
# *************************************************
# Balance
# the number of unique levels are:  1570
#
#
# 0       7810
# 1448     272
# 1597     236
# 1573     229
# 1587     222
#         ...
# 1372       1
# 1320       1
# 1057       1
# 1401       1
# 1304       1
# Name: Balance, Length: 1570, dtype: int64
#
#
# the number of Null values are:  0
# *************************************************
# Age
# the number of unique levels are:  62
#
#
# 25    1041
# 84     908
# 40     829
# 50     742
# 46     741
#       ...
# 82     246
# 26     200
# 29     181
# 28     179
# 27     175
# Name: Age, Length: 62, dtype: int64
#
#
# the number of Null values are:  0

# %% [markdown]
# ## There are no Duplicate Values

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head(10)
# Out:
#     Income  Limit  Rating  Cards  Balance  Age Marital Status  Gender  \
# 0  105.038   9142     734      3      232   30        Married    Male
# 1   69.820   4223     389      1      924   71        Married    Male
# 2   17.441   2430     253      1       20   46      Seperated    Male
# 3   39.368   3829     248      3      813   42        Married  Female
# 4   56.375   2850     258      1      109   30        Married    Male
# 5   53.016   6136     574      2      438   52      Unmarried  Female
# 6   48.586   5941     357      3      409   65        Married    Male
# 7   16.429   2594     120      4        0   25        Married  Female
# 8   39.606   3796     215      3       29   37      Unmarried    Male
# 9   23.672   6164     417      4     1448   62      Unmarried    Male
#
#           Ethnicity           Education
# 0         Caucasian              Master
# 1             Asian            Bachelor
# 2  African American    Senior Secondary
# 3         Caucasian    Senior Secondary
# 4  African American           Doctorate
# 5         Caucasian          Elementary
# 6         Caucasian  Senior High School
# 7  African American            Bachelor
# 8         Caucasian    Senior Secondary
# 9         Caucasian              Master

# %% [markdown]
# ### Utilize descriptive statistics to understand the dataset's key features and distributions

# %%
df.describe()
# Out:
#              Income         Limit        Rating         Cards       Balance  \
# count  32547.000000  32547.000000  32547.000000  32547.000000  32547.000000
# mean      46.490372   4419.522322    326.720159      2.906658    447.894706
# std       37.140511   2202.441042    136.146945      1.325485    454.205934
# min       10.627000   1134.000000    119.000000      1.000000      0.000000
# 25%       20.661500   2727.000000    224.000000      2.000000      5.000000
# 50%       33.469000   4178.000000    316.000000      3.000000    331.000000
# 75%       58.075000   5636.000000    405.000000      4.000000    749.000000
# max      160.231000  11200.000000    805.000000      7.000000   1597.000000
#
#                 Age
# count  32547.000000
# mean      55.476419
# std       16.990896
# min       25.000000
# 25%       42.000000
# 50%       55.000000
# 75%       69.000000
# max       86.000000

# %%
df.describe(include = "O")
# Out:
#        Marital Status  Gender  Ethnicity Education
# count           32547   32547      32547     32547
# unique              5       2          3         8
# top         Unmarried  Female  Caucasian    Master
# freq            16829   16562      16380      8781

# %% [markdown]
# ## Renaming and combing the features in Marital Status column

# %%
df.rename(columns = {'Rating': 'Cibil_Score'},inplace = True)

# %%
df.rename(columns={"Marital Status":"Marital_Status"}, inplace = True)

# %%
df['Marital_Status'].value_counts()
# Out:
# Unmarried    16829
# Married      15621
# Divorced        51
# Seperated       37
# Widow            9
# Name: Marital_Status, dtype: int64

# %% [markdown]
# ## Rounding off Income by 2 decimal points.

# %%
df['Income']= round(df['Income'],2)

# %% [markdown]
# ## Combining divorced and seperated as they both mean the same.

# %%
df.replace({'Marital_Status': {'Divorced':'Seperated'}},inplace = True)

# %%
df.Marital_Status.value_counts()
# Out:
# Unmarried    16829
# Married      15621
# Seperated       88
# Widow            9
# Name: Marital_Status, dtype: int64

# %% [markdown]
# ## Checking if there are any outliers

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.dtypes
# Out:
# Income            float64
# Limit               int64
# Cibil_Score         int64
# Cards               int64
# Balance             int64
# Age                 int64
# Marital_Status     object
# Gender             object
# Ethnicity          object
# Education          object
# dtype: object

# %% [markdown]
# ### Create insightful visualizations, including histograms, box plots, and scatter plots, to identify trends and anomalies

# %%
   # Setting up the plots
plt.figure(figsize=(14,15))
sns.set_style(style='whitegrid')

    # Plot 1 
plt.subplot(4,3,1)
sns.boxplot(x='Income',data=df)

    # Plot 2
plt.subplot(4,3,2)
sns.boxplot(x='Limit',data=df)

    # Plot 3 
plt.subplot(4,3,3)
sns.boxplot(x='Cibil_Score',data=df)

    # Plot 4
plt.subplot(4,3,4)
sns.boxplot(x='Cards',data=df)

    # Plot 5
plt.subplot(4,3,5)
sns.boxplot(x='Balance',data=df)

    # Plot 6 
plt.subplot(4,3,6)
sns.boxplot(x='Age',data=df)
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# ### Seems like there are outliers in Income variable, but cant remove it as it could be actuals.

# %% [markdown]
# ## Analyze categorical features using pie charts and bar plots to understand their distributions.

# %% [markdown]
# ## Univariate Analysis on each of the Categorical Variables

# %%
 ## list of categorical variables together
cat_vars = ['Marital_Status', 'Gender', 'Ethnicity', 'Education']

    ## create figure with subplots
fig, axs = plt.subplots(nrows=2,ncols = 2,figsize=(8,6))
axs = axs.flatten()

    ## create histplot for each categorical var
for i, var in enumerate(cat_vars):
    sns.histplot(x = var, data = df, ax=axs[i])
    axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation = 90)

    ## adjusting spacing between  subplots 
fig.tight_layout()

plt.show()
# Out:
# C:\Users\Amit\AppData\Local\Temp\ipykernel_11188\4010065669.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation = 90)
# C:\Users\Amit\AppData\Local\Temp\ipykernel_11188\4010065669.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation = 90)
# C:\Users\Amit\AppData\Local\Temp\ipykernel_11188\4010065669.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation = 90)
# C:\Users\Amit\AppData\Local\Temp\ipykernel_11188\4010065669.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation = 90)

# %%
ax =sns.countplot(x = df['Marital_Status'],
                 order = df['Marital_Status'].value_counts(ascending = False).index, palette = 'terrain');

abs_values = df['Marital_Status'].value_counts(ascending = False).values

ax.bar_label(container=ax.containers[0], labels = abs_values);

# %%
fig = plt.figure(figsize = (4,4))
ax = sns.countplot(x=df['Gender'],
                   order=df['Gender'].value_counts(ascending=False).index,);

abs_values = df['Gender'].value_counts(ascending=False).values

ax.bar_label(container=ax.containers[0], labels=abs_values);

plt.show()

# %%
ax = sns.countplot(x = df['Ethnicity'],
                  order = df['Ethnicity'].value_counts(ascending  = False).index);

abs_values= df['Ethnicity'].value_counts(ascending  = False).values

ax.bar_label(container = ax.containers[0], labels = abs_values);

# %%
fig= plt.figure(figsize=(12,6))

ax = sns.countplot(x = df["Education"],
                   order = df['Education'].value_counts(ascending = False).index);
abs_values = df['Education'].value_counts(ascending = False).values

ax.bar_label(container = ax.containers[0], labels = abs_values);

plt.show()

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Univariate Analysis on Continuous Variables

# %%
cont_vars
# Out:
# ['Income', 'Limit', 'Rating', 'Cards', 'Balance', 'Age']

# %%
sns.histplot(df['Income'],kde=True);

# %%
df['Income'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df['Limit'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
fig = plt.figure(figsize=(6,3))
sns.histplot(df['Limit'],kde = True)
plt.show();

# %%
df['Cibil_Score'].plot(kind = 'box');

# %%
sns.histplot(df['Cibil_Score'], kde = True);

# %%
df['Cards'].plot(kind = 'box');

# %%
sns.displot(df['Balance']);

# %%
df['Balance'].plot(kind = 'box');

# %%
sns.histplot(df['Age']);

# %%
df['Age'].plot(kind = 'box');

# %% [markdown]
# ### *************************************************************************************************************************************

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize = (10,5))
sns.barplot(x = 'Balance', y = 'Education', data = df,errorbar = None,
            order = df['Education'].value_counts(ascending = False).index);
abs_values = df['Education'].value_counts(ascending = False).values

ax.bar_label(container = ax.containers[0], labels = abs_values);

plt.show()

# %%
sns.lmplot(y = 'Cibil_Score', x = "Limit", data = df)

# %% [markdown]
# ## There seems to be some correlation between Cibil_Score and Limit Variable.

# %%
sns.lmplot(y = 'Balance', x = 'Cibil_Score', data  = df);

# %% [markdown]
# ## Balance and Cibil_Score also has some good correlation.

# %%
sns.lmplot(y = 'Balance', x = 'Limit', data  = df);

# %% [markdown]
# ## Looks Limit and Balance are highly correlated.
# ## We will confirm that while doing Multivariate analysis.

# %%
cat_vars
# Out:
# ['Marital_Status', 'Gender', 'Ethnicity', 'Education']

# %%
cont_vars
# Out:
# ['Income', 'Limit', 'Rating', 'Cards', 'Balance', 'Age']

# %%
# Comparison between genders based on Income and Marital_Status
plt.figure(figsize = (10, 5))
ax = sns.barplot(y = 'Income', x = 'Marital_Status', data = df, hue= 'Gender', errorbar = None, palette = 'ocean')
ax.bar_label(ax.containers[0])
for i in ax.containers:
    ax.bar_label(i,);
plt.show();

# %% [markdown]
# ## On an average femal widows have higher income levels.

# %% [markdown]
# ###### ***************************************************************************************************************************************************************************

# %%
# Comparison between genders based on Limit and Marital_Status
plt.figure(figsize = (10, 5))
ax = sns.barplot(y = 'Limit', x = 'Marital_Status', data = df, hue= 'Gender', errorbar = None, palette = 'icefire')
ax.bar_label(ax.containers[0])
for i in ax.containers:
    ax.bar_label(i,)
plt.show();

# %% [markdown]
# ## It is evident that male widows have higher credit limit.

# %% [markdown]
# ###### ***************************************************************************************************************************************************************************

# %% [markdown]
# # Assess the impact of education level on credit limits by comparing different groups.¶

# %%
# Comparison between Limit and Education
plt.figure(figsize = (12, 7))
ax = sns.barplot(y = 'Limit', x = 'Education', data = df, errorbar = None, palette = 'icefire')
ax.bar_label(ax.containers[0])
for i in ax.containers:
    ax.bar_label(i,)
plt.show();

# %% [markdown]
# ## People having Education level as Secondary and Senior High School have Higher limit as compared to others

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Calculate the average number of cards owned by individuals and analyze its relationship with credit limits

# %%
# Comparison between genders based on Limit and No.of credit cards
plt.figure(figsize = (12, 6))
ax = sns.barplot(y = 'Limit', x = 'Cards', data = df, hue= 'Gender', errorbar = None, palette = 'icefire')
ax.bar_label(ax.containers[0])
for i in ax.containers:
    ax.bar_label(i,)
plt.show();

# %% [markdown]
# ## Females have more no.of credit cards with higher limits amongst all.

# %% [markdown]
# ##### ===================================================================================================================

# %%
# Comparison between genders based on Cibil_Score and Marital_Status
plt.figure(figsize = (10, 5))
ax = sns.barplot(y = 'Cibil_Score', x = 'Marital_Status', data = df, hue= 'Gender', errorbar = None, palette = 'afmhot')
ax.bar_label(ax.containers[0])
for i in ax.containers:
    ax.bar_label(i,)
plt.show();

# %% [markdown]
# ## Widows(female) have better Cibil_Score.

# %% [markdown]
# ##### **************************************************************************************************************************************************************************

# %%
# Comparison between genders based on Cards and Marital_Status
plt.figure(figsize = (10, 5))
ax = sns.barplot(y = 'Cards', x = 'Marital_Status', data = df, hue= 'Gender', errorbar = None, palette = 'bone')
ax.bar_label(ax.containers[0])
for i in ax.containers:
    ax.bar_label(i,);
plt.show();

# %% [markdown]
# ## Widows(male) tend to have more number of credit cards.

# %% [markdown]
# #### ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Comparison between genders based on Age and Marital_Status
plt.figure(figsize = (10,5))
ax = sns.barplot(y = 'Age', x = 'Marital_Status', data = df, hue= 'Gender', errorbar = None, palette = 'summer')
ax.bar_label(ax.containers[0])
for i in ax.containers:
    ax.bar_label(i,);

# %% [markdown]
# ## Widows(female) are the oldest.

# %% [markdown]
# #### ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## From all the above graphs we can infer that:
# ### ->Widow's have better Balance, Income and a very good Cibil_Score(Rating) in all the segments.

# %% [markdown]
# ## Conduct correlation analysis to identify the relationships between numerical variables.

# %% [markdown]
# ## Multivariate Analysis

# %%
plt.figure(figsize = (6,3))
sns.heatmap(df.corr(), annot = True)
plt.show();

# %%
df_num = df.select_dtypes(include= ['float64', "int64"])

# %%
df_num_corr = df_num.corr()['Limit'][:-1] # -1 because the latest row is Limit
golden_features_list = df_num_corr[abs(df_num_corr) > 0.5].sort_values(ascending=False)
print("There are {} strongly correlated values with Limit:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There are 3 strongly correlated values with Limit:
# Limit          1.000000
# Cibil_Score    0.629210
# Balance        0.539445
# Name: Limit, dtype: float64

# %% [markdown]
# **Inferences:**
#
#  **> Limit is highly corelated to Rating and Balance**

# %% [markdown]
# ## Apply data transformation techniques (e.g., logarithmic transformation) to normalize skewed variables.

# %%
df['Income'].skew()
# Out:
# 1.5472517627646538

# %%
df['log_income'] = np.log(df['Income'])

# %%
df['log_income']
# Out:
# 0        4.654341
# 1        4.245921
# 2        2.858766
# 3        3.673004
# 4        4.032114
#            ...
# 32542    3.494384
# 32543    2.523326
# 32544    4.161536
# 32545    3.043093
# 32546    3.565015
# Name: log_income, Length: 32547, dtype: float64

# %%
df['Limit'].skew()
# Out:
# 0.7630435269451619

# %%
df['log_limit'] = np.log(df['Limit'])

# %%
df['log_limit']
# Out:
# 0        9.120634
# 1        8.348301
# 2        7.795647
# 3        8.250359
# 4        7.955074
#            ...
# 32542    8.348064
# 32543    8.638525
# 32544    8.044305
# 32545    7.212294
# 32546    8.206038
# Name: log_limit, Length: 32547, dtype: float64

# %%
df['Balance'].skew()
# Out:
# 0.8981077917405278

# %%
df['log_balance']= np.log(df['Balance'])
# Out:
# C:\Users\Amit\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df['log_balance']
# Out:
# 0        5.446737
# 1        6.828712
# 2        2.995732
# 3        6.700731
# 4        4.691348
#            ...
# 32542    5.087596
# 32543    6.188264
# 32544    6.356108
# 32545        -inf
# 32546    5.170484
# Name: log_balance, Length: 32547, dtype: float64

# %%
sns.regplot(y = 'Income', x = 'Limit', data  = df, scatter_kws={"color": "green"}, line_kws={"color": "red"});

# %% [markdown]
# ## There seems to be linear relationship between Limit and Income

# %% [markdown]
# ## ---------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Evaluate the distribution of account balances and identify individuals with high or low balances

# %%
# Comparison between genders based on Balance and Marital_Status
plt.figure(figsize = (10, 5))
ax = sns.barplot(y = 'Balance', x = 'Marital_Status', data = df, hue= 'Gender', errorbar = None, palette = 'icefire')
ax.bar_label(ax.containers[0])
for i in ax.containers:
    ax.bar_label(i,)
plt.show();

# %% [markdown]
# ## Widows(Male) have higher balance as compared to others.
